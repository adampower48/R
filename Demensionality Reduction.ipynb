# %%
library(datasets)

# %%
# help(datasets)
library(help=datasets)

# %%
x = rnorm(1000)
y = rnorm(1000)

# %%
plot(x, y)
# Out:
# plot without title

# %%
z = cbind(x, y)

# %%
var(z)
# Out:
#   x          y
# x  1.0221324 -0.0747311
# y -0.0747311  0.9608894

# %%
x1 = 2*x+y
y1 = 2*x-y
z1 = cbind(x1, y1)

# %%
plot(x1, y1)
# Out:
# plot without title

# %%
var(z1)
# Out:
#    x1       y1
# x1 4.750495 3.127640
# y1 3.127640 5.348344

# %%
z1
# Out:
#       x1         y1
#  [1,]  2.0759534  3.0283336
#  [2,]  3.3573278  3.4885940
#  [3,]  1.4114688  2.0106206
#  [4,] -2.9366587 -2.6501231
#  [5,] -3.0868155  1.1944796
#  [6,]  0.2051092  0.4993637
#  [7,]  1.6390749  0.6674607
#  [8,]  3.5342077  3.8449286
#  [9,] -2.9143905 -0.3052271
# [10,]  0.1303829  0.5937373
# [11,]  3.4228035  1.7143700
# [12,] -2.7926629 -2.0894369
# [13,]  0.2827359  2.2884388
# [14,]  1.2179143  2.6384180
# [15,] -5.0086209 -3.1176750
# [16,]  0.3606141  1.3889627
# [17,]  4.9693983  0.8410201
# [18,] -4.4759298 -3.0939036
# [19,] -0.9491347  1.0018273
# [20,]  2.4966141  0.2831291
# [21,] -0.7284415 -1.1517704
# [22,] -0.1957479  3.2898592
# [23,]  0.8925146 -1.6058244
# [24,] -0.8698755  0.3899701
# [25,] -2.2888062  1.2105172
# [26,] -6.3833971 -2.0974668
# [27,]  3.6675895  6.0176245
# [28,]  4.6924239 -1.2185912
# [29,] -1.4182476 -0.2996240
# [30,]  0.4803453  3.4526072
# [31,] <U+22EE>   <U+22EE>
# [32,] -0.3029583 -0.3746939
# ...

# %%
e = eigen(var(z1))
e
# Out:
# eigen() decomposition
# $values
# [1] 8.191312 1.907526
#
# $vectors
#           [,1]       [,2]
# [1,] 0.6726286 -0.7399802
# [2,] 0.7399802  0.6726286

# %%
plot(z1 %*% e$vectors, asp=1)
# Out:
# plot without title

# %%
e = eigen(var(ChickWeight))
e

# %%
e
# Out:
# eigen() decomposition
# $values
# [1] 5090.4108596  207.3516305   12.6188336    0.1196867
#
# $vectors
#             [,1]        [,2]         [,3]         [,4]
# [1,] 0.996113750  0.03229288  0.081920992 -0.001875635
# [2,] 0.079403248  0.07326138 -0.994030504  0.015206941
# [3,] 0.037951818 -0.99395648 -0.071360713 -0.074282013
# [4,] 0.003490055 -0.07510293  0.009997798  0.997119558

# %%
e$vectors[,1:4]
# Out:
#      [,1]        [,2]        [,3]         [,4]
# [1,] 0.996113750  0.03229288  0.081920992 -0.001875635
# [2,] 0.079403248  0.07326138 -0.994030504  0.015206941
# [3,] 0.037951818 -0.99395648 -0.071360713 -0.074282013
# [4,] 0.003490055 -0.07510293  0.009997798  0.997119558
